# %%
from visiomode_analysis import subject, session
import glob
import pandas as pd

# %%
session_files = glob.glob("../*trials.csv")

subject_sessions = []
for session_file in session_files:
    subject_sessions.append(session.summary(session_file))

subject_df = pd.DataFrame(subject_sessions)
# Out:
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
subject_df = subject_df.sort_values("session_date").reset_index(drop=True)

# %%
subject_df["session_id"] = subject_df.index + 1

# %%
subject_df["task_session"] = subject_df.groupby(["animal_id", "protocol"], sort=False)["session_id"].rank(
    ascending=True
)

# %%
subject_df
# Out:
#   animal_id session_date    protocol environment experiment  correct  \
# 0     MM229   2022-03-01  targetonly     unknown  109hrb21d      166
# 1     MM229   2022-03-09      gonogo     unknown  109hrb21d       61
#
#    correct_wc  incorrect  incorrect_wc  correction_trials  ...        rt  \
# 0         166          0             0                  0  ...  3.505884
# 1         100         40            81                 41  ...  0.757996
#
#       rt_wc   rt_hits  rt_hits_wc  rt_false_alarms  rt_false_alarms_wc  \
# 0  3.505884  3.505884    3.505884              NaN                 NaN
# 1  0.775277  0.841125    0.841125         0.724478            0.754815
#
#      rt_iqr  rt_iqr_wc  session_id  task_session
# 0  4.261229   4.261229           1           1.0
# 1  0.694114   0.814639           2           1.0
#
# [2 rows x 45 columns]

# %%
subject.collate_sessions("../")
# Out:
# ['../sub-MM229_exp-109hrb21d_ses-20220309_behaviour-gonogo_trials.csv', '../sub-MM229_exp-109hrb21d_ses-20220301_behaviour-targetonly_trials.csv']
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/celefthe/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 subject.collate_sessions("../")
#
# File ~/Projects/visiomode_analysis/src/visiomode_analysis/subject/__init__.py:59, in collate_sessions(directory, output_dir)
#      56 subject_df = pd.DataFrame(subject_sessions)
#      58 subject_df.sort_values("session_date", inplace=True)
# ---> 59 subject_df["task_session"] = subject_df.groupby(["animal_id", "protocol"], sort=False).index.rank(ascending=True)
#      60 return subject_df
#
# File ~/Projects/visiomode_analysis/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1115, in GroupBy.__getattr__(self, attr)
#    1112 if attr in self.obj:
#    1113     return self[attr]
# -> 1115 raise AttributeError(
#    1116     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1117 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'index'
